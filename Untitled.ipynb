# %%
#dataframe and data manipulation
import pandas as pd
import numpy as np

#data viz
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("MELBOURNE_HOUSE_PRICES_LESS.csv")

# %% [markdown]
# # Data Exploration

# %% [markdown]
# Let's look at the details of both datasets.

# %%
df.head(10)
# Out:
#          Suburb            Address  Rooms Type      Price Method  \
# 0    Abbotsford      49 Lithgow St      3    h  1490000.0      S
# 1    Abbotsford      59A Turner St      3    h  1220000.0      S
# 2    Abbotsford      119B Yarra St      3    h  1420000.0      S
# 3    Aberfeldie         68 Vida St      3    h  1515000.0      S
# 4  Airport West   92 Clydesdale Rd      2    h   670000.0      S
# 5  Airport West       4/32 Earl St      2    t   530000.0      S
# 6  Airport West     3/74 Hawker St      2    u   540000.0      S
# 7  Airport West  1/26 Highridge Cr      3    h   715000.0     SP
# 8     Albanvale      1 Jackson Cct      6    h        NaN     PI
# 9   Albert Park        18 Mills St      3    h  1925000.0      S
#
#          SellerG       Date  Postcode             Regionname  Propertycount  \
# 0         Jellis  1/04/2017      3067  Northern Metropolitan           4019
# 1       Marshall  1/04/2017      3067  Northern Metropolitan           4019
# ...

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Postcode', 'Regionname', 'Propertycount', 'Distance',
#        'CouncilArea'],
#       dtype='object')

# %%
df.shape
# Out:
# (63023, 13)

# %%
print("Type values: {}".format(df.Type.unique()))
print("Method values: {}".format(df.Method.unique()))
# Out:
# Type values: ['h' 't' 'u']
# Method values: ['S' 'SP' 'VB' 'PI' 'SA']

# %%
df.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Postcode           int64
# Regionname        object
# Propertycount      int64
# Distance         float64
# CouncilArea       object
# dtype: object

# %%
df.describe()[['Price','Distance']]
#Price and Distance are the only columns that we can compute statistics on
# Out:
#               Price      Distance
# count  4.843300e+04  63023.000000
# mean   9.978982e+05     12.684829
# std    5.934989e+05      7.592015
# min    8.500000e+04      0.000000
# 25%    6.200000e+05      7.000000
# 50%    8.300000e+05     11.400000
# 75%    1.220000e+06     16.700000
# max    1.120000e+07     64.100000

# %%
df.isnull().any()
# Out:
# Suburb           False
# Address          False
# Rooms            False
# Type             False
# Price             True
# Method           False
# SellerG          False
# Date             False
# Postcode         False
# Regionname       False
# Propertycount    False
# Distance         False
# CouncilArea      False
# dtype: bool

# %%
df.isnull().sum() / df.shape[0] #get percentage of data that have null values
# Out:
# Suburb           0.000000
# Address          0.000000
# Rooms            0.000000
# Type             0.000000
# Price            0.231503
# Method           0.000000
# SellerG          0.000000
# Date             0.000000
# Postcode         0.000000
# Regionname       0.000000
# Propertycount    0.000000
# Distance         0.000000
# CouncilArea      0.000000
# dtype: float64

# %% [markdown]
# From this, it is crucial to note that around 23% of the houses have no prices, meaning that they are not valuable when training the model - however we could apply the model onto these houses for fun after model validation.
#
# We can easily pull all the houses with null prices from the main dataframe and into a seperate one.

# %%
null_prices = df[df['Price'].isnull()]
null_prices
# Out:
#                  Suburb                Address  Rooms Type  Price Method  \
# 8             Albanvale          1 Jackson Cct      6    h    NaN     PI
# 15       Altona Meadows           57 Tatman Dr      4    h    NaN     SN
# 24            Ashburton              1 Pitt St      4    h    NaN      S
# 29              Attwood     46 Threadneedle St      4    h    NaN     SN
# 38         Balwyn North            12 Agnes Av      3    h    NaN     SP
# ...                 ...                    ...    ...  ...    ...    ...
# 63001      Wyndham Vale          15 Yaltara Dr      3    h    NaN      S
# 63008        Yarraville  4/247 Williamstown Rd      3    t    NaN      S
# 63010           Burwood           29 Summit Rd      4    h    NaN     PN
# 63021        Thomastown         3/1 Travers St      3    u    NaN     PI
# 63022  Williams Landing            1 Diadem Wy      4    h    NaN     SP
#
#              SellerG        Date  Postcode             Regionname  \
# ...

# %%
df = df.drop(df[df['Price'].isnull()].index)

# %%
plt.figure(figsize=(10,5))
plt.ylabel('Price')
sns.boxplot(x=df['Price'])
plt.show()
